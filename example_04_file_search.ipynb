# %% [markdown]
# File Search
# https://platform.openai.com/docs/guides/tools?tool-type=file-search

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
response = client.responses.create(
    model="gpt-5-nano",
    input="Quem descobriu a América?",
    tools=[{
        "type": "file_search",
        "vector_store_ids": [os.getenv("VECTOR_STORE_ID")]
    }]
)
print(response.output_text)
# Out:
# Não há uma resposta única. A pergunta depende de qual perspectiva você adota sobre “descoberta”.
#
# - Povos nativos já habitavam o continente há muito tempo. Há evidências de ocupação de cerca de 13 mil anos atrás, vindas da América do Norte a partir de migrações da Ásia via a ponte de gelo do Estreito de Bering.
# - Os vikings, liderados por Eric, o Vermelho, teriam chegado à região de Labrador por volta do ano 1000, ou seja, cerca de mil anos atrás.
# - Do ponto de vista europeu, Cristóvão Colombo chegou às Bahamas em 1492, achando que havia chegado às Índias. Assim, para muitos historiadores, Colombo “descobriu” a América para a Europa.
# - O nome América acabou popularizado por Américo Vespúcio, com a ajuda de um mapa elaborado por Waldseemüller em 1507, após relatos de Vespúcio. Esse mapa acabou batizando o novo continente com o nome América. fileciteturn0file1turn0file2
# - Em algumas leituras históricas, aponta-se que Vespúcio reconheceu que as terras não eram as Índias e sim um continente novo, o que influenciou a visão europeia sobre a região.
# - Se quiser uma síntese acessível com mais contexto, há a referência do livro “A Quarta Parte do Mundo” de Toby Lester mencionada no material de apoio.
#
# Se preferir, posso resumir tudo em 1–2 frases rápidas.

# %%
for output in response.output:
    print(output.type)
# Out:
# reasoning
# file_search_call
# reasoning
# message

# %%
for output in response.output:
    if output.type == "file_search_call":
        print(output)
# Out:
# ResponseFileSearchToolCall(id='fs_0a2778f815db4b8900690df6cba44481958c2371fb70386926', queries=['Quem descobriu a América?', 'Cristóvão Colombo descobriu a América?', 'Quais povos chegaram à América antes dos europeus?', 'Quem chegou à América em 1492?', 'Qual é a explicação histórica sobre a descoberta da América?'], status='completed', type='file_search_call', results=None)
