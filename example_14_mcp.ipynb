# %% [markdown]
# ## MCP

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
response = client.responses.create(
    model="gpt-5-nano",
    input="Qual é a disponibilidade do produto 'Alo Yoga Align Legging'?",
     tools=[{
          "type": "mcp",
          "server_label": "aloyoga",
          "server_url": "https://www.aloyoga.com/api/mcp",
          "require_approval": "never"
      }]
)

# %%
response.output_text
# Out:
# 'Resumo da disponibilidade atual:\n\n- Airlift High-Waist Alignment Legging - Smoky Quartz/White (link: https://www.aloyoga.com/products/w54180r-airlift-high-waist-alignment-legging-smoky-quartz-white)\n  - Tamanho disponível: M\n  - Disponibilidade: Em estoque\n  - Preço: USD 144.00\n\nObservações:\n- Outras variantes da Smoky Quartz/White (XXS, XS, S, L) não estão disponíveis no momento.\n- Black/White em todas as variantes estão esgotadas.\n\nPosso:\n- Adicionar a variante M ao carrinho (ou criar/usar um carrinho existente)?\n- Buscar outras opções similares com disponibilidade?'

# %%
for output in response.output:
    print(output.type)
# Out:
# mcp_list_tools
# reasoning
# mcp_call
# reasoning
# mcp_call
# reasoning
# mcp_call
# reasoning
# message
