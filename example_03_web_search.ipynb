# %% [markdown]
# Web Search
# https://platform.openai.com/docs/guides/tools?tool-type=web-search

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
response = client.responses.create(
    model="gpt-5-nano",
    input="Quem descobriu a América?",
    tools=[{
        "type": "web_search"
    }],
)
print(response.output_text)
# Out:
# Depende de como você encara “descobrir”:
#
# - Povos indígenas já viviam na América há milhares de anos antes de qualquer europeu. Então, em termos de ocupação humana, a América não foi “descoberta” por uma única pessoa, mas habitada há muito tempo por diferentes culturas.
#
# - Os vikings foram os primeiros europeus conhecidos a chegar ao continente, por volta do ano 1000, estabelecendo-se brevemente em Vinland (L’Anse-aux-Meadows, no que hoje é o Canadá).
#
# - Cristóvão Colombo, a serviço da Espanha, é tradicionalmente citado como quem “descobriu” a América para a visão europeia, ao chegar ao que hoje é Bahamas em 12 de outubro de 1492, abrindo contato duradouro entre Europa e as Américas.
#
# - Em termos de maior alcance de exploração europeia, Portugal chegou ao Brasil com Pedro Álvares Cabral em 22 de abril de 1500.
#
# Resumo: não houve apenas uma pessoa que descobriu a América. A história inclui ocupação indígena muito antiga, a chegada viking por volta do ano 1000, e o contato europeu iniciado por Colombo em 1492 (com continuidade a partir de 1500 com os portugueses no Brasil). Quer que eu aprofunde algum dos pontos?

# %%
for output in response.output:
    print(output.type)
# Out:
# reasoning
# message
