# %% [markdown]
# https://platform.openai.com/docs/guides/streaming-responses
# https://platform.openai.com/docs/api-reference/responses-streaming/response

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

# %%
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
response = client.responses.create(
    model="gpt-5-nano",
    input="Quem descobriu a América? Explique em detalhes.",
    stream=True,
)

# %%
for event in response:
    if (event.type == "response.output_text.delta"):
        print(event.delta, end="", flush=True)
# Out:
# Depende do que você entende por “descobrir”. A expressão costuma soar simples, mas a história é complexa e envolve várias fases e perspectivas.
#
# Resumo rápido
# - Antes de qualquer europeu chegar, já havia povos vivendo na América há milênios. Não é correto dizer que “ninguém conhecia” a América antes.
# - A primeira evidência bem documentada de contato europeu com parte da América ocorreu com os vikings por volta do ano 1000, no que hoje é Terra-Norte-Americana (Vinlândia, em Newfoundland).
# - A “descoberta” da América para a Europa, e a abertura de uma era de exploração e colonização em grande escala, é geralmente associada a Cristóvão Colombo, em 1492, patrocinado pelos reis católicos da Espanha.
# - O termo “descoberta” pode ser enganoso: envolve encontros entre mundos, com impactos profundos — inclusive devastação indígena e intercâmbio de plantas, animais e doenças.
#
# Detalhes por fases
#
# 1) Povos já estabelecidos na América antes dos europeus
# - Américas eram habitadas há milhares de anos por uma enorme diversidade de povos e civilizações.
#   - Na Mesoamérica: Olmecas, Maias, Teotihuacanos, Astecas (contribuíram com grandes centros urbanos, astronomia, escrita e agricultura em redes comerciais).
#   - Na região Andina (Sul-americana): culturas como Caral/Supe, Moche, Nazca, Wari e, mais tarde, os Incas, com vastos sistemas de estradas, agricultura em terraços e grande organização estatal.
#   - Na América do Norte e no Caribe: civilizações e culturas diversas, incluindo os povos algonquíns, iroqueses, pueblos (Anasazi/Pueblo), Mississipiana, entre outros, com distintas formas de vida, agricultura e comércio.
# - Essa presença demonstra que a América não foi “descoberta” do nada; já havia sociedades complexas vivendo ali.
#
# 2) Os vikings e o primeiro contato europeu documentado (por volta de 1000)
# - Os vikings, liderados por Leif Erikson, estabeleceram assentamentos em Vinlândia (L’Anse aux Meadows, atual Canadá) por volta do século X.
# - Esse contato é o registro europeu mais antigo de passagem próxima à América do Norte. Não resultou em colonização duradoura nem em desenho de uma rota de comércio global, mas mostra que Europa já conhecia há muito tempo parte do Atlântico com alcance até a região norte do continente americano.
#
# 3) Colombo e a “descoberta” europeia da América (1492)
# - Cristóvão Colombo, apoiado pelos Reis Católicos da Espanha, partiu em 1492 buscando uma rota ocidental para as Índias. A ideia era encontrar uma rota marítima para as riquezas da Ásia contornando a África.
# - Em 12 de outubro de 1492 chegou a terras que hoje sabemos ficarem no arquipélago das Bahamas (ele chamou de San Salvador). Ele acreditava ter alcançado as Índias; na prática, ele chegou a um novo continente para os europeus.
# - Esse evento é visto como o marco que inaugurou uma era de exploração europeia, colonização, e, muitas vezes, violência e transformação demográfica nas Américas.
# - Importante notar: Colombo não “descobriu” a América para o mundo todo, e muito menos para as populações que já viviam lá. Ele abriu caminho para a expansão europeia.
#
# 4) Consequências históricas — o intercâmbio colombino
# - Columbian Exchange (Trocas Columbinas): transferência de plantas, animais, pessoas e doenças entre Velho e Novo Mundo.
#   - Do Novo Mundo para o Velho Mundo: milho, batata, tomate, pimentas, cacau, abacate, abóbora, ervilhas, etc.
#   - Do Velho Mundo para o Novo Mundo: trigo, arroz, batata-doce (em alguns lugares), açúcar, porcos, cavalos, vacas, gripe, varíola e outras doenças.
# - Efeito demográfico: doenças trazidas pelos europeus devastaram populações indígenas em várias regiões, reduzindo drasticamente a população em muitos lugares.
# - Efeito político e econômico: inicia a colonização europeia em larga escala, criação de impérios, redes comerciais transatlânticas e mudanças profundas nas culturas locais.
#
# 5) Por que é importante a nuance?
# - A ideia de “descoberta” deve ser usada com cuidado.
#   - Indígenas já viviam nas Américas há muito tempo (não foram descobertas por acaso; havia conhecimento do território entre povos vizinhos).
#   - Os vikings foram os primeiros europeus conhecidos a chegar ao leste do Canadá, muito antes de Colombo.
#   - Colombo representa o início de uma nova era de contato entre continentes que teve consequências profundas para a história global.
# - Em termos modernos, muitos preferem falar em “encurtar o Atlântico” ou “abrir caminhos de contato” em vez de dizer que alguém descobriu a América pela primeira vez.
#
# Se quiser, eu posso:
# - Montar uma linha do tempo com datas-chave.
# - Listar leituras recomendadas, fontes históricas e evidências arqueológicas sobre cada fase.
# - Responder a perguntas específicas (por exemplo, sobre o papel dos vikings, sobre o Columbian Exchange, ou sobre as consequências para populações específicas).
